# %%
import sqlite3 as db
import pandas as pd

# %%
conn = db.connect("AML_DB.db")

# %%
date_range = """
08.01.2020
08.02.2020
08.03.2020
08.04.2020
08.05.2020
08.06.2020
08.07.2020
08.08.2020
08.09.2020
08.10.2020
08.11.2020
08.12.2020
08.13.2020
08.14.2020
08.15.2020
08.16.2020
08.17.2020
08.18.2020
08.19.2020
08.20.2020
08.21.2020
08.22.2020
08.23.2020
08.24.2020
08.25.2020
08.26.2020
08.27.2020
08.28.2020
08.29.2020
08.30.2020
08.31.2020
09.01.2020
09.02.2020
09.03.2020
09.04.2020
09.05.2020
09.06.2020
09.07.2020
09.08.2020
09.09.2020
09.10.2020
09.11.2020
09.12.2020
09.13.2020
09.14.2020
09.15.2020
09.16.2020
09.17.2020
09.18.2020
09.19.2020
09.20.2020
09.21.2020
09.22.2020
09.23.2020
09.24.2020
09.25.2020
09.26.2020
09.27.2020
09.28.2020
09.29.2020
09.30.2020
""".split()

# %%
for date in date_range:
    tab = "All Active Moves"
    folder = '/Users/timhulak/Desktop/Syracuse/MBC-638/Project/AllMovesList/'
    file_name = f"All Moves List {date}.xlsx"
    file = pd.ExcelFile(folder+file_name)
    data = pd.read_excel(file, tab, skiprows=1)
    late_data = data[data['Late Status'] == 'Late']
    date = date.replace(".",'/')
    late_data['AML_Date'] = date
    late_data.to_sql('AllMoves',con=conn, index=False, if_exists='append')
    test = pd.read_sql("""SELECT * FROM AllMoves""", con=conn)
    print(f"{date}: {test.shape}")
# Out:
# /Users/timhulak/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/timhulak/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
# 08/01/2020: (6459, 44)
# 08/02/2020: (13793, 44)
# 08/03/2020: (21621, 44)
# 08/04/2020: (29464, 44)
# 08/05/2020: (38011, 44)
# 08/06/2020: (46062, 44)
# 08/07/2020: (52241, 44)
# 08/08/2020: (58912, 44)
# 08/09/2020: (65817, 44)
# 08/10/2020: (72540, 44)
# 08/11/2020: (80385, 44)
# 08/12/2020: (86967, 44)
# 08/13/2020: (93383, 44)
# ...
